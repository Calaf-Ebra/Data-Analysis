# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
import os;
os.listdir('/kaggle/input')
# Out:
# ['womens-ecommerce-clothing-reviews']

# %%
data=pd.read_csv("../input/womens-ecommerce-clothing-reviews/Womens Clothing E-Commerce Reviews.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %% [markdown]
# **Cleaning the data**

# %%
ddf.fillna(method='pad')
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %% [markdown]
# **Making insights about rating?**

# %%
df[['Rating']].describe()
# Out:
#              Rating
# count  23486.000000
# mean       4.196032
# std        1.110031
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# **How to know full details of each department?**

# %%
a=df.groupby([df['Department Name'], df['Rating']])
a.first()
# Out:
#                         Unnamed: 0  Clothing ID  Age  \
# Department Name Rating
# Bottoms         1              214         1020   67
#                 2              237         1066   42
#                 3               16         1065   34
#                 4               15         1065   47
#                 5                3         1049   50
# Dresses         1              389         1104   38
#                 2                5         1080   49
#                 3                2         1077   60
#                 4               21         1080   55
#                 5                1         1080   34
# Intimate        1               61          368   36
#                 2               56          368   33
#                 3               25          697   31
#                 4                0          767   33
#                 5               13          767   44
# Jackets         1             1510          977   31
# ...

# %%
sns.countplot(x=df['Division Name'])
# Out:
# <AxesSubplot:xlabel='Division Name', ylabel='count'>

# %%
sns.countplot(x=df.Rating)
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
sns.barplot(x=df['Positive Feedback Count'], y=df['Division Name'])
# Out:
# <AxesSubplot:xlabel='Positive Feedback Count', ylabel='Division Name'>

# %% [markdown]
# **Age and Rating-correlation**

# %%
sns.relplot(x=df['Age'],y=df['Rating'],kind="line",hue=df['Division Name'],ci=None,markers=True)

# %%
sns.relplot(x=df['Age'],y=df['Positive Feedback Count'],kind="line",hue=df['Division Name'],ci=None,markers=True)

# %% [markdown]
# **How age affects rating of items from different departments?**

# %%
sns.set_style("darkgrid")
sns.set_palette("bright")
sns.relplot(x=df['Age'],y=df['Positive Feedback Count'],col=df['Department Name'],kind="scatter",ci=None, markers=True)
plt.show()

# %% [markdown]
# **Does that numbers matter? Will depend on number of people within that raange
# ,We can use a histogram to check that**

# %%
plt.style.use('seaborn')
plt.hist(x=df.Age)
plt.xlabel("Range of Age for Customers")
plt.ylabel("Number of P")
plt.show()
